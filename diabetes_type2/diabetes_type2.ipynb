# %%
import pandas as pd

# %%
df = pd.read_csv("Type_2_diabetes.csv")
df
# Out:
#       pubmed_id                                              title  \
# 0      36800717  Association of Hepcidin levels in Type 2 Diabe...
# 1      36800554  A National Physician Survey of Deintensifying ...
# 2      36800530  Gastrointestinal Consequences of Type 2 Diabet...
# 3      36800369  An older diabetes-induced mice model for study...
# 4      36800286  GLP-1 Receptor Agonists and Risk of Adverse Ce...
# ...         ...                                                ...
# 9461   35727760  Bilirubin levels and kidney function decline A...
# 9462   35727611  Associations Between Implementation of the Car...
# 9463   35727580  Efficacy and Safety of Varenicline for Smoking...
# 9464   30644346                                         StatPearls
# 9465   30644346                                         StatPearls
#
#                                                abstract
# 0     To evaluate the impact of hepcidin and ferriti...
# ...
