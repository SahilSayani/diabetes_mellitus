# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Dataset Diabetes Type1 (Total).csv")
df
# Out:
#                  Age     Sex Area of Residence            HbA1c  Height  \
# 0    greater then 15  Female           Suburban       Over 7.5%    1.50
# 1    greater then 15  Female           Suburban       Over 7.5%    1.48
# 2       Less then 11  Female              Urban       Over 7.5%    1.20
# 3       Less then 15  Female           Suburban       Over 7.5%    1.65
# 4       Less then 15  Female           Suburban       Over 7.5%    1.61
# ..               ...     ...                ...             ...     ...
# 301     Less then 11    Male              Urban  Less then 7.5%    1.01
# 302     Less then 11  Female           Suburban  Less then 7.5%    0.92
# 303      Less then 5  Female           Suburban  Less then 7.5%    0.61
# 304     Less then 11  Female           Suburban  Less then 7.5%    0.92
# 305      Less then 5  Female              Urban  Less then 7.5%    0.61
#
#      Weight        BMI Duration of disease   Other diease Adequate Nutrition   \
# ...

# %%
df.isnull().sum()
# Out:
# Age                                           0
# Sex                                           0
# Area of Residence                             0
# HbA1c                                         0
# Height                                        0
# Weight                                        0
# BMI                                           0
# Duration of disease                           0
# Other diease                                  0
# Adequate Nutrition                            0
# Education of Mother                           0
# Standardized growth-rate in infancy           0
# Standardized birth weight                     0
# Autoantibodies                                0
# Impaired glucose metabolism                   0
# Insulin taken                                 0
# How Taken                                     0
# Family History affected in Type 1 Diabetes    0
# Family History affected in Type 2 Diabetes    0
# Hypoglycemis                                  0
# ...

# %%
df1=df[['Family History affected in Type 1 Diabetes','Family History affected in Type 2 Diabetes']]
df1
# Out:
#     Family History affected in Type 1 Diabetes  \
# 0                                          Yes
# 1                                          Yes
# 2                                          Yes
# 3                                           No
# 4                                          Yes
# ..                                         ...
# 301                                         No
# 302                                         No
# 303                                         No
# 304                                         No
# 305                                        Yes
#
#     Family History affected in Type 2 Diabetes
# 0                                           No
# 1                                          Yes
# 2                                           No
# 3                                          Yes
# 4                                          Yes
# ..                                         ...
# 301                                        Yes
# ...

# %%
Family_history_in_Diabetes1=pd.read_csv('Dataset15Q.csv')# data if the family has any diabetes 1 history
Family_history_in_Diabetes2=pd.read_csv('Dataset16Q.csv')# data if the family has any diabetes 2 history
diabetes_attributes = pd.read_csv('Dataset20Q.csv')

# %%
Family_history_in_Diabetes1
# Out:
#     15a(Father) 15b(Mother) 15c(Fathers Heredity) 15d(Mothers Heredity)  \
# 0            No         Yes                    No                   Yes
# 1           Yes         Yes                    No                   Yes
# 2            No         Yes                   Yes                    No
# 3            No          No                    No                    No
# 4           Yes          No                    No                    No
# ..          ...         ...                   ...                   ...
# 301          No          No                    No                    No
# 302          No          No                    No                    No
# 303          No          No                    No                    No
# 304          No          No                    No                    No
# 305          No          No                    No                   Yes
#
#     Affected
# 0        yes
# 1        yes
# 2        yes
# 3        yes
# 4        yes
# ..       ...
# ...

# %%
Family_history_in_Diabetes2
# Out:
#     16a(Father) 16b(Mother) 16c(Fathers Heredity) 16d(Mothers Heredity)  \
# 0            No          No                    No                    No
# 1            No          No                    No                    No
# 2            No          No                    No                    No
# 3            No          No                    No                    No
# 4            No          No                    No                    No
# ..          ...         ...                   ...                   ...
# 301          No          No                   Yes                    No
# 302          No          No                    No                    No
# 303          No          No                    No                    No
# 304         Yes         Yes                   Yes                    No
# 305          No          No                    No                    No
#
#     Affected
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
# ..       ...
# ...

# %%
df.dtypes
# Out:
# Age                                            object
# Sex                                            object
# Area of Residence                              object
# HbA1c                                          object
# Height                                        float64
# Weight                                        float64
# BMI                                           float64
# Duration of disease                            object
# Other diease                                   object
# Adequate Nutrition                             object
# Education of Mother                            object
# Standardized growth-rate in infancy            object
# Standardized birth weight                      object
# Autoantibodies                                 object
# Impaired glucose metabolism                    object
# Insulin taken                                  object
# How Taken                                      object
# ...

# %%
df.describe()
# Out:
#            Height      Weight         BMI
# count  306.000000  306.000000  306.000000
# mean     1.349346   38.854575   20.860711
# std      0.277601   16.689427    6.225745
# min      0.440000    5.000000   10.077936
# 25%      1.220000   25.000000   16.928286
# 50%      1.420000   40.000000   19.813209
# 75%      1.560000   50.000000   23.711124
# max      1.830000   87.000000   61.983471

# %%
df['HbA1c'].unique()
# Out:
# array(['Over 7.5%', 'Less then 7.5%'], dtype=object)

# %% [markdown]
# label Encoder for converting object into integer or float data type

# %%
df=df.drop(['Duration of disease','How Taken'],axis=1)

# %%
df.shape
# Out:
# (306, 20)
